# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.metrics import accuracy_score, r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
# calling dataset
df= pd.read_csv("cardekho.csv")

# %%
df.drop("name", axis=1, inplace=True)

# %%
df
# Out:
#       year  selling_price  km_driven    fuel seller_type transmission  \
# 0     2014         450000     145500  Diesel  Individual       Manual
# 1     2014         370000     120000  Diesel  Individual       Manual
# 2     2006         158000     140000  Petrol  Individual       Manual
# 3     2010         225000     127000  Diesel  Individual       Manual
# 4     2007         130000     120000  Petrol  Individual       Manual
# ...    ...            ...        ...     ...         ...          ...
# 8123  2013         320000     110000  Petrol  Individual       Manual
# 8124  2007         135000     119000  Diesel  Individual       Manual
# 8125  2009         382000     120000  Diesel  Individual       Manual
# 8126  2013         290000      25000  Diesel  Individual       Manual
# 8127  2013         290000      25000  Diesel  Individual       Manual
#
#                      owner  mileage(km/ltr/kg)  engine max_power  seats
# ...

# %%
# checking null values
df.isnull().sum()
# Out:
# year                    0
# selling_price           0
# km_driven               0
# fuel                    0
# seller_type             0
# transmission            0
# owner                   0
# mileage(km/ltr/kg)    221
# engine                221
# max_power             215
# seats                 221
# dtype: int64

# %%
df.shape
# Out:
# (8128, 11)

# %%
# removing all null values
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (7907, 11)

# %%
# again checking
df.isnull().sum()
# Out:
# year                  0
# selling_price         0
# km_driven             0
# fuel                  0
# seller_type           0
# transmission          0
# owner                 0
# mileage(km/ltr/kg)    0
# engine                0
# max_power             0
# seats                 0
# dtype: int64

# %% [markdown]
# ### Checking number of unique values

# %%
df["fuel"].value_counts()
# Out:
# fuel
# Diesel    4299
# Petrol    3520
# CNG         53
# LPG         35
# Name: count, dtype: int64

# %%
df["seller_type"].value_counts()
# Out:
# seller_type
# Individual          6564
# Dealer              1107
# Trustmark Dealer     236
# Name: count, dtype: int64

# %%
df["owner"].value_counts()
# Out:
# owner
# First Owner             5215
# Second Owner            2017
# Third Owner              510
# Fourth & Above Owner     160
# Test Drive Car             5
# Name: count, dtype: int64

# %%
df["transmission"].value_counts()
# Out:
# transmission
# Manual       6866
# Automatic    1041
# Name: count, dtype: int64

# %%
df["max_power"].unique()
# Out:
# array(['74', '103.52', '78', '90', '88.2', '81.86', '57.5', '37', '67.1',
#        '68.1', '108.45', '60', '73.9', '67', '82', '88.5', '46.3',
#        '88.73', '64.1', '98.6', '88.8', '83.81', '83.1', '47.3', '73.8',
#        '34.2', '35', '81.83', '40.3', '121.3', '138.03', '160.77',
#        '117.3', '116.3', '83.14', '67.05', '168.5', '100', '120.7',
#        '98.63', '175.56', '103.25', '171.5', '100.6', '174.33', '187.74',
#        '170', '78.9', '88.76', '86.8', '108.495', '108.62', '93.7',
#        '103.6', '98.59', '189', '67.04', '68.05', '58.2', '82.85', '81.8',
#        '73', '120', '94.68', '160', '65', '155', '69.01', '126.32',
#        '138.1', '83.8', '126.2', '98.96', '62.1', '86.7', '188', '214.56',
#        '177', '280', '148.31', '254.79', '190', '177.46', '204', '141',
#        '117.6', '241.4', '282', '150', '147.5', '108.5', '103.5', '183',
#        '181.04', '157.7', '164.7', '91.1', '400', '68', '75', '85.8',
# ...

# %% [markdown]
# ### doing ordinal encoding on categorial columns

# %%
cat_cols=["fuel", "seller_type", "transmission", "owner"]

# %%
oe= OrdinalEncoder()
df[oe.get_feature_names_out()]= oe.fit_transform(df[cat_cols])
df
# Out:
#       year  selling_price  km_driven  fuel  seller_type  transmission  owner  \
# 0     2014         450000     145500   1.0          1.0           1.0    0.0
# 1     2014         370000     120000   1.0          1.0           1.0    2.0
# 2     2006         158000     140000   3.0          1.0           1.0    4.0
# 3     2010         225000     127000   1.0          1.0           1.0    0.0
# 4     2007         130000     120000   3.0          1.0           1.0    0.0
# ...    ...            ...        ...   ...          ...           ...    ...
# 8123  2013         320000     110000   3.0          1.0           1.0    0.0
# 8124  2007         135000     119000   1.0          1.0           1.0    1.0
# 8125  2009         382000     120000   1.0          1.0           1.0    0.0
# 8126  2013         290000      25000   1.0          1.0           1.0    0.0
# 8127  2013         290000      25000   1.0          1.0           1.0    0.0
#
# ...

# %% [markdown]
# ### checking relations between columns

# %%
df.dtypes
# Out:
# year                    int64
# selling_price           int64
# km_driven               int64
# fuel                  float64
# seller_type           float64
# transmission          float64
# owner                 float64
# mileage(km/ltr/kg)    float64
# engine                float64
# max_power              object
# seats                 float64
# dtype: object

# %%
# changing datatype of max_power from object to float
df["max_power"]=pd.to_numeric(df['max_power'],errors = 'coerce')

# %%
df.isnull().sum()
# Out:
# year                  0
# selling_price         0
# km_driven             0
# fuel                  0
# seller_type           0
# transmission          0
# owner                 0
# mileage(km/ltr/kg)    0
# engine                0
# max_power             1
# seats                 0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# year                  0
# selling_price         0
# km_driven             0
# fuel                  0
# seller_type           0
# transmission          0
# owner                 0
# mileage(km/ltr/kg)    0
# engine                0
# max_power             0
# seats                 0
# dtype: int64

# %%
df.dtypes
# Out:
# year                    int64
# selling_price           int64
# km_driven               int64
# fuel                  float64
# seller_type           float64
# transmission          float64
# owner                 float64
# mileage(km/ltr/kg)    float64
# engine                float64
# max_power             float64
# seats                 float64
# dtype: object

# %%
# checking relations
df.corr()
# Out:
#                         year  selling_price  km_driven      fuel  seller_type  \
# year                1.000000       0.412302  -0.428548 -0.040414    -0.144423
# selling_price       0.412302       1.000000  -0.222158 -0.193332    -0.337022
# km_driven          -0.428548      -0.222158   1.000000 -0.270453     0.120516
# fuel               -0.040414      -0.193332  -0.270453  1.000000     0.110267
# seller_type        -0.144423      -0.337022   0.120516  0.110267     1.000000
# transmission       -0.249002      -0.590269   0.201186 -0.034839     0.230112
# owner              -0.472522      -0.224413   0.281945 -0.030725     0.142435
# mileage(km/ltr/kg)  0.328544      -0.126280  -0.172980 -0.083432    -0.019847
# engine              0.018263       0.455682   0.206031 -0.486471    -0.091856
# max_power           0.226598       0.749674  -0.038159 -0.282335    -0.248180
# seats              -0.007923       0.041617   0.227259 -0.341640     0.052688
#
# ...

# %%
# plotting heatmap
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), cmap= "Blues", annot=True, fmt= ".1g", cbar=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Labeling input and output columns

# %%
X= df.drop("selling_price", axis=1)
Y=df["selling_price"]

# %%
# splitting data into train and test data
X_train, X_test, y_train, y_test= train_test_split(X,Y, test_size=0.2, random_state=2)

# %% [markdown]
# ### Using Linear Regression

# %%
lr= LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
print ("r2_score for linear regression is :", r2_score(y_test, y_pred))
# Out:
# r2_score for linear regression is : 0.6815695749129497

# %% [markdown]
# ### Using Lasso Regression

# %%
lasso= Lasso(alpha=1, max_iter=1000)
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=1)

# %%
y_pred2= lasso.predict(X_test)

# %%
print ("r2_score for lasso regression is :", r2_score(y_test, y_pred2))
# Out:
# r2_score for lasso regression is : 0.6815692210429842

# %% [markdown]
# ### Using RandomForestRegression

# %%
rfr= RandomForestRegressor()
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred3= rfr.predict(X_test)

# %%
print ("r2_score for RandomForestRegression is :", r2_score(y_test, y_pred3))
# Out:
# r2_score for RandomForestRegression is : 0.9681806049536944
